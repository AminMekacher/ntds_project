# %%
# !git --version
# Out:
# git version 2.18.0

# %%
# !python --version
# Out:
# Python 3.7.0

# %%
# !jupyter --version
# Out:
# 4.4.0

# %%
# !ipython --version
# Out:
# 6.5.0

# %%
import numpy as np

# %%
import scipy

# %%
import dj
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-7d347a2e73f6> in <module>()
# ----> 1 import dj
#
# ModuleNotFoundError: No module named 'dj'

# %%
import pandas as pd

# %%
import matplotlib as mpl

# %%
import networkx as nx

# %%
import pygsp

# %%
# %matplotlib inline
# Out:
# /Users/aminmekacher/miniconda3/envs/ntds_2018/lib/python3.7/site-packages/matplotlib/font_manager.py:229: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
graph = pygsp.graphs.Logo()
graph.estimate_lmax()
filt = pygsp.filters.Heat(graph, tau=100)
DELTAS = [20, 30, 1090]
signal = np.zeros(graph.N)
signal[DELTAS] = 1
signal = filt.filter(signal)
graph.plot_signal(signal, highlight=DELTAS)
