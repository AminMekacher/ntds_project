# %%
from mpl_toolkits.basemap import Basemap
from shapely.geometry import Point, MultiPoint
import pandas as pd
import matplotlib.pyplot as plt
import mplleaflet
import matplotlib.cm as cm
import matplotlib.colors as co
import numpy as np
import random

#1 North America 2 Central America 3 South America
#4 East Asia 5 Southeast Asia 6 South Asia 7 Central Asia 12 Oceania
#8 Western Europe 9 Eastern Europe
#10 Middle East 11 Sub-saharian Africa

dataframe = pd.read_csv('1417_processed.csv',
                       usecols=["eventid", "country", "country_txt", "region", "longitude", "latitude", "iyear", "nkill", "gname",
                                     "attacktype1", "attacktype1_txt", "targtype1", "targtype1_txt", "weaptype1",
                                     "weaptype1_txt", "nkillter", "weapsubtype1", "weapsubtype1_txt", "targsubtype1",
                                     "targsubtype1_txt", "provstate", "city"])
dataframe.columns
# Out:
# Index(['eventid', 'iyear', 'country', 'country_txt', 'region', 'provstate',
#        'city', 'latitude', 'longitude', 'attacktype1', 'attacktype1_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'gname', 'weaptype1', 'weaptype1_txt', 'weapsubtype1',
#        'weapsubtype1_txt', 'nkill', 'nkillter'],
#       dtype='object')

# %%
middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=10, 
        llcrnrlat=10,
        urcrnrlon=65,
        urcrnrlat=40,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

middle_dataframe = dataframe.loc[dataframe['region'] == 10 ] #europe and middle east
middle_dataframe0 = middle_dataframe.loc[middle_dataframe['nkill'] == 0 ]
middle_dataframe1 = middle_dataframe.loc[middle_dataframe['nkill'] > 0 ]

middle_points0 = pd.Series(
                [Point(middle(mapped_x, mapped_y))
                 for mapped_x, mapped_y in zip(middle_dataframe0['longitude'], 
                                               middle_dataframe0['latitude'])])
middle_points1 = pd.Series(
                [Point(middle(mapped_x, mapped_y))
                 for mapped_x, mapped_y in zip(middle_dataframe1['longitude'], 
                                               middle_dataframe1['latitude'])])

plt.clf()
fig = plt.figure()
ax = fig.add_subplot(111, facecolor='w', frame_on=False)
fig.set_size_inches(18.5, 10.5)

dev = middle.scatter(
            [geom.x for geom in middle_points0],
            [geom.y for geom in middle_points0],
            20, marker='o', lw=.25,
            facecolor='blue', edgecolor='w', label='No fatality',
            alpha=0.9,antialiased=True,
            zorder=2)
dev = middle.scatter(
            [geom.x for geom in middle_points1],
            [geom.y for geom in middle_points1],
            20, marker='o', lw=.25,
            facecolor='red', edgecolor='w', label='One or more death(s)',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
plt.title('Middle East : Attacks from 2014 to 2017')
plt.legend()
plt.savefig("middle_deaths.png")

# %%
"""
We first plot the nodes corresponding to important (number of casualties higher than 50) on the map, for both African 
and Middle East regions, and we use a color code to discriminates attacks claimed by :
 * ISIL
 * AQAP (Al-Qaeda in the Arabian Peninsula)
 * Boko Haram
 * Unclaimed attacks or attacks claimed by another terrorist group
"""

middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-5, 
        llcrnrlat=-5,
        urcrnrlon=65,
        urcrnrlat=40,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

middle_dataframe = dataframe.loc[dataframe['nkill'] >= 10 ]
middle_dataframe = middle_dataframe.loc[middle_dataframe['region'] >= 10 ] #middle east
middle_dataframe = middle_dataframe.loc[middle_dataframe['region'] <= 11 ] #sub-saharan africa
middle_dataframe.reset_index(inplace = True)

bokoharam_dataframe = middle_dataframe.loc[middle_dataframe['gname'] == 'Boko Haram' ]
bokoharam_dataframe.reset_index(inplace = True)
isil_dataframe = middle_dataframe.loc[middle_dataframe['gname'] == 'Islamic State of Iraq and the Levant (ISIL)' ]
isil_dataframe.reset_index(inplace = True)
aqap_dataframe = middle_dataframe.loc[middle_dataframe['gname'] == 'Al-Qaida in the Arabian Peninsula (AQAP)' ]
aqap_dataframe.reset_index(inplace = True)

unclassified_dataframe = middle_dataframe.loc[middle_dataframe['gname'] != 'Boko Haram' ]
unclassified_dataframe = unclassified_dataframe.loc[middle_dataframe['gname'] != 'Islamic State of Iraq and the Levant (ISIL)' ]
unclassified_dataframe = unclassified_dataframe.loc[middle_dataframe['gname'] != 'Al-Qaida in the Arabian Peninsula (AQAP)' ]
unclassified_dataframe.reset_index(inplace = True)

classified_dataframe = pd.concat([middle_dataframe,unclassified_dataframe]).drop_duplicates(subset = ['eventid'], keep=False) 


bokoharam_points = pd.Series(
                [Point(middle(mapped_x, mapped_y))
                 for mapped_x, mapped_y in zip(bokoharam_dataframe['longitude'], 
                                               bokoharam_dataframe['latitude'])])
isil_points = pd.Series(
                [Point(middle(mapped_x, mapped_y))
                 for mapped_x, mapped_y in zip(isil_dataframe['longitude'], 
                                               isil_dataframe['latitude'])])

aqap_points = pd.Series(
                [Point(middle(mapped_x, mapped_y))
                 for mapped_x, mapped_y in zip(aqap_dataframe['longitude'], 
                                               aqap_dataframe['latitude'])])
unclassified_points = pd.Series(
                [Point(middle(mapped_x, mapped_y))
                 for mapped_x, mapped_y in zip(unclassified_dataframe['longitude'], 
                                               unclassified_dataframe['latitude'])])

plt.clf()
fig = plt.figure()
ax = fig.add_subplot(111, facecolor='w', frame_on=False)
fig.set_size_inches(18.5, 10.5)

total_nodes = middle_dataframe['longitude'].size
unclassified_nodes = unclassified_dataframe['longitude'].size

dev = middle.scatter(
            [geom.x for geom in bokoharam_points],
            [geom.y for geom in bokoharam_points],
            20, marker='o', lw=.25,
            facecolor='blue', edgecolor='w', label='Boko Haram',
            alpha=0.9,antialiased=True,
            zorder=2)
dev = middle.scatter(
            [geom.x for geom in isil_points],
            [geom.y for geom in isil_points],
            20, marker='o', lw=.25,
            facecolor='red', edgecolor='w', label='ISIL',
            alpha=0.9,antialiased=True,
            zorder=2)
dev = middle.scatter(
            [geom.x for geom in aqap_points],
            [geom.y for geom in aqap_points],
            20, marker='o', lw=.25,
            facecolor='green', edgecolor='w', label='Al-Qaida',
            alpha=0.9,antialiased=True,
            zorder=2)
dev = middle.scatter(
            [geom.x for geom in unclassified_points],
            [geom.y for geom in unclassified_points],
            20, marker='o', lw=.25,
            facecolor='black', edgecolor='w', label='Others',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
plt.title('Attacks from 2014 to 2017 in the Middle East and Africa')
plt.legend()
plt.savefig("groups.png")
# Out:
# /Users/aminmekacher/miniconda3/envs/ntds_project/lib/python3.6/site-packages/ipykernel_launcher.py:38: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
"""
To determine where the stronghold of each of these three organizations lies between the years, we computed the number of
civilians killed by each aforementioned group. To see if there has been any substantial difference throughout the years 
(a group losing strength or moving their stronghold), we plotted the number of casualties for each studied year
"""

middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-15, 
        llcrnrlat=-30,
        urcrnrlon=65,
        urcrnrlat=50,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

columns = ['country_txt', 'nkill', 'gname', 'iyear']
middle_casualties = pd.DataFrame(middle_dataframe, columns=columns)

affected_countries = middle_casualties['country_txt'].unique()
terrorist_groups = np.array(['Islamic State of Iraq and the Levant (ISIL)', 'Boko Haram', 'Al-Qaida in the Arabian Peninsula (AQAP)',
                   'Others'])

casualties_matrix_2014 = np.zeros((affected_countries.size, terrorist_groups.size))
casualties_matrix_2015 = np.zeros((affected_countries.size, terrorist_groups.size))
casualties_matrix_2016 = np.zeros((affected_countries.size, terrorist_groups.size))
casualties_matrix_2017 = np.zeros((affected_countries.size, terrorist_groups.size))

for index, rows in middle_casualties.iterrows():
    country_index = np.where(rows['country_txt'] == affected_countries)
    group_index = np.where(rows['gname'] == terrorist_groups)[0]
    year_index = rows['iyear']
    
    if (len(group_index) == 0):
        group_index = 3
        
    if year_index == 2014: casualties_matrix_2014[country_index, group_index] += rows['nkill'];
    elif year_index ==  2015: casualties_matrix_2015[country_index, group_index] += rows['nkill'];
    elif year_index ==  2016: casualties_matrix_2016[country_index, group_index] += rows['nkill'];
    elif year_index ==  2017: casualties_matrix_2017[country_index, group_index] += rows['nkill'];
    
    
# We create a pandas dataframe with the affected countries and their latitude and longitude, by taking their respective 
# capitals as references

country_data = {'country': ['Iraq', 'Nigeria', 'Syria', 'Central African Republic',
                           'South Sudan', 'Yemen', 'Mali', 'Somalia', 'Sudan',
                           'Libya', 'Algeria', 'Kenya', 'Egypt', 'Uganda',
                           'Lebanon', 'Cameroon', 'West Bank and Gaza Strip',
                           'Democratic Republic of Congo', 'Niger', 'Chad',
                           'Tunisia', 'Iran', 'Saudi Arabia', 'Kuwait',
                           'Turkey', 'Burkina Faso', 'Mozambique', 'Ethiopia',
                           'Burundi', 'Ivory Coast', 'Republic of the Congo', 'Jordan'], 
                'longitude': [44.3, 7.32, 36.18, 18.35, 
                              31.57, 44.19, -7.55, 45.25, 32.35,
                              13.18, 3.08, 36.48, 31.14, 32.3,
                             35.31, 11.35, 34.47,
                             15.15, 2.06, 14.59,
                             10.11, 51.3, 46.42, 48,
                             32.54, -1.3, 32.32, 38.42,
                             29.18, -5.17, 15.12, 35.52],
                'latitude': [33.2, 9.05, 33.3, 4.23, 
                             4.86, 15.37, 12.34, 2.02, 15.31,
                             32.89, 36.42, -1.17, 30.01, 0.2,
                            33.53, 3.5, 31.5,
                            -4.2, 13.27, 12.1,
                            36.5, 35.44, 24.41, 29.3,
                            39.57, 12.15, -25.58, 9.02,
                            -3.16, 6.49, -4.09, 31.57]}

country_dataframe = pd.DataFrame(data=country_data)

# We add new columns to this new dataframe with the number of casualties for each considered terrorist group

for i in range(0, 4):
    column_2014 = casualties_matrix_2014[:, i]
    label_2014 = terrorist_groups[i] + " " + str(2014)
    country_dataframe[label_2014] = column_2014
    
    column_2015 = casualties_matrix_2015[:, i]
    label_2015 = terrorist_groups[i] + " " + str(2015)
    country_dataframe[label_2015] = column_2015
    
    column_2016 = casualties_matrix_2016[:, i]
    label_2016 = terrorist_groups[i] + " " + str(2016)
    country_dataframe[label_2016] = column_2016
    
    column_2017 = casualties_matrix_2017[:, i]
    label_2017 = terrorist_groups[i] + " " + str(2017)
    country_dataframe[label_2017] = column_2017
    
    
casualties_points = pd.Series(
                    [Point(middle(mapped_x, mapped_y))
                     for mapped_x, mapped_y in zip(country_dataframe['longitude'], 
                                               country_dataframe['latitude'])])

plt.clf()
fig = plt.figure()
ax = fig.add_subplot(221, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Boko Haram 2014'], marker='o', lw=1.1,
            facecolor='none', edgecolor='blue',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Islamic State of Iraq and the Levant (ISIL) 2014'], marker='o', lw=1.1,
            facecolor='none', edgecolor='red',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Al-Qaida in the Arabian Peninsula (AQAP) 2014'], marker='o', lw=1.1,
            facecolor='none', edgecolor='green', 
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Others 2014'], marker='o', lw=1.1,
            facecolor='none', edgecolor='black',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
ax.set_title('Casualties in 2014')
plt.legend()

for area in [100, 600, 2000]:
    plt.scatter([], [], facecolor='none', edgecolor='black', alpha=0.3, s=area,
                label=str(area), lw=2)
plt.legend(scatterpoints=1, frameon=False, labelspacing=3, title='Number of casualties',
          bbox_to_anchor=(1.25, 0.9), bbox_transform=ax.transAxes)

middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-15, 
        llcrnrlat=-30,
        urcrnrlon=65,
        urcrnrlat=50,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

ax = fig.add_subplot(222, facecolor='w', frame_on=False)
fig.set_size_inches(15.5, 10.5)
    
dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Boko Haram 2015'], marker='o', lw=1.1,
            facecolor='none', edgecolor='blue',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Islamic State of Iraq and the Levant (ISIL) 2015'], marker='o', lw=1.1,
            facecolor='none', edgecolor='red',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Al-Qaida in the Arabian Peninsula (AQAP) 2015'], marker='o', lw=1.1,
            facecolor='none', edgecolor='green', 
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Others 2015'], marker='o', lw=1.1,
            facecolor='none', edgecolor='black',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
ax.set_title('Casualties in 2015')
plt.legend()

middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-15, 
        llcrnrlat=-30,
        urcrnrlon=65,
        urcrnrlat=50,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

ax = fig.add_subplot(223, facecolor='w', frame_on=False)
fig.set_size_inches(15.5, 10.5)
    
dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Boko Haram 2016'], marker='o', lw=1.1,
            facecolor='none', edgecolor='blue',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Islamic State of Iraq and the Levant (ISIL) 2016'], marker='o', lw=1.1,
            facecolor='none', edgecolor='red',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Al-Qaida in the Arabian Peninsula (AQAP) 2016'], marker='o', lw=1.1,
            facecolor='none', edgecolor='green', 
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Others 2016'], marker='o', lw=1.1,
            facecolor='none', edgecolor='black',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
ax.set_title('Casualties in 2016')
plt.legend()

for area in [100, 600, 2000]:
    plt.scatter([], [], facecolor='none', edgecolor='black', alpha=0.3, s=area,
                label=str(area), lw=2)
plt.legend(scatterpoints=1, frameon=False, labelspacing=3, title='Number of casualties',
          bbox_to_anchor=(1.25, 0.9), bbox_transform=ax.transAxes)

middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-15, 
        llcrnrlat=-30,
        urcrnrlon=65,
        urcrnrlat=50,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

ax = fig.add_subplot(224, facecolor='w', frame_on=False)
fig.set_size_inches(15.5, 10.5)
    
dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Boko Haram 2017'], marker='o', lw=1.1,
            facecolor='none', edgecolor='blue',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Islamic State of Iraq and the Levant (ISIL) 2017'], marker='o', lw=1.1,
            facecolor='none', edgecolor='red',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Al-Qaida in the Arabian Peninsula (AQAP) 2017'], marker='o', lw=1.1,
            facecolor='none', edgecolor='green', 
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Others 2017'], marker='o', lw=1.1,
            facecolor='none', edgecolor='black',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
ax.set_title('Casualties in 2017')
plt.legend()
plt.savefig("casualties.png")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
"""
Another interesting data vizualisation to consider is to see how many casualties each terrorist group had to suffer during
these four years. Analyzing the two maps side-by-side could help us notice if any group lost their grip on a 
specific territory due to the army or other militia's retaliation
"""

middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-15, 
        llcrnrlat=-30,
        urcrnrlon=65,
        urcrnrlat=50,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

columns = ['country_txt', 'nkillter', 'gname', 'iyear']
middle_casualties_ter = pd.DataFrame(middle_dataframe, columns=columns)

affected_countries_ter = middle_casualties_ter['country_txt'].unique()

casualties_ter_2014 = np.zeros((affected_countries_ter.size, terrorist_groups.size))
casualties_ter_2015 = np.zeros((affected_countries_ter.size, terrorist_groups.size))
casualties_ter_2016 = np.zeros((affected_countries_ter.size, terrorist_groups.size))
casualties_ter_2017 = np.zeros((affected_countries_ter.size, terrorist_groups.size))

for index, rows in middle_casualties_ter.iterrows():
    if (~np.isnan(rows['nkillter'])):
        country_index = np.where(rows['country_txt'] == affected_countries_ter)
        group_index = np.where(rows['gname'] == terrorist_groups)[0]
        year_index = rows['iyear']

        if (len(group_index) == 0):
            group_index = 3

        if year_index == 2014: casualties_ter_2014[country_index, group_index] += rows['nkillter'];
        elif year_index ==  2015: casualties_ter_2015[country_index, group_index] += rows['nkillter'];
        elif year_index ==  2016: casualties_ter_2016[country_index, group_index] += rows['nkillter'];
        elif year_index ==  2017: casualties_ter_2017[country_index, group_index] += rows['nkillter'];
            
country_dataframe = pd.DataFrame(data=country_data)

# We add new columns to this new dataframe with the number of casualties for each considered terrorist group

for i in range(0, 4):
    column_2014 = casualties_ter_2014[:, i]
    label_2014 = terrorist_groups[i] + " " + str(2014)
    country_dataframe[label_2014] = column_2014
    
    column_2015 = casualties_ter_2015[:, i]
    label_2015 = terrorist_groups[i] + " " + str(2015)
    country_dataframe[label_2015] = column_2015
    
    column_2016 = casualties_ter_2016[:, i]
    label_2016 = terrorist_groups[i] + " " + str(2016)
    country_dataframe[label_2016] = column_2016
    
    column_2017 = casualties_ter_2017[:, i]
    label_2017 = terrorist_groups[i] + " " + str(2017)
    country_dataframe[label_2017] = column_2017
    
    
casualties_points = pd.Series(
                    [Point(middle(mapped_x, mapped_y))
                     for mapped_x, mapped_y in zip(country_dataframe['longitude'], 
                                               country_dataframe['latitude'])])

plt.clf()
fig = plt.figure()
ax = fig.add_subplot(221, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Boko Haram 2014'], marker='o', lw=1.1,
            facecolor='none', edgecolor='blue',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Islamic State of Iraq and the Levant (ISIL) 2014'], marker='o', lw=1.1,
            facecolor='none', edgecolor='red',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Al-Qaida in the Arabian Peninsula (AQAP) 2014'], marker='o', lw=1.1,
            facecolor='none', edgecolor='green', 
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Others 2014'], marker='o', lw=1.1,
            facecolor='none', edgecolor='black',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
ax.set_title('Casualties in 2014')
plt.legend()

for area in [100, 600, 2000]:
    plt.scatter([], [], facecolor='none', edgecolor='black', alpha=0.3, s=area,
                label=str(area), lw=2)
plt.legend(scatterpoints=1, frameon=False, labelspacing=3, title='Number of casualties',
          bbox_to_anchor=(1.25, 0.9), bbox_transform=ax.transAxes)

middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-15, 
        llcrnrlat=-30,
        urcrnrlon=65,
        urcrnrlat=50,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

ax = fig.add_subplot(222, facecolor='w', frame_on=False)
fig.set_size_inches(15.5, 10.5)
    
dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Boko Haram 2015'], marker='o', lw=1.1,
            facecolor='none', edgecolor='blue',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Islamic State of Iraq and the Levant (ISIL) 2015'], marker='o', lw=1.1,
            facecolor='none', edgecolor='red',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Al-Qaida in the Arabian Peninsula (AQAP) 2015'], marker='o', lw=1.1,
            facecolor='none', edgecolor='green', 
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Others 2015'], marker='o', lw=1.1,
            facecolor='none', edgecolor='black',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
ax.set_title('Casualties in 2015')
plt.legend()

middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-15, 
        llcrnrlat=-30,
        urcrnrlon=65,
        urcrnrlat=50,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

ax = fig.add_subplot(223, facecolor='w', frame_on=False)
fig.set_size_inches(15.5, 10.5)
    
dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Boko Haram 2016'], marker='o', lw=1.1,
            facecolor='none', edgecolor='blue',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Islamic State of Iraq and the Levant (ISIL) 2016'], marker='o', lw=1.1,
            facecolor='none', edgecolor='red',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Al-Qaida in the Arabian Peninsula (AQAP) 2016'], marker='o', lw=1.1,
            facecolor='none', edgecolor='green', 
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Others 2016'], marker='o', lw=1.1,
            facecolor='none', edgecolor='black',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
ax.set_title('Casualties in 2016')
plt.legend()

for area in [100, 600, 2000]:
    plt.scatter([], [], facecolor='none', edgecolor='black', alpha=0.3, s=area,
                label=str(area), lw=2)
plt.legend(scatterpoints=1, frameon=False, labelspacing=3, title='Number of casualties',
          bbox_to_anchor=(1.25, 0.9), bbox_transform=ax.transAxes)

middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-15, 
        llcrnrlat=-30,
        urcrnrlon=65,
        urcrnrlat=50,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

ax = fig.add_subplot(224, facecolor='w', frame_on=False)
fig.set_size_inches(15.5, 10.5)
    
dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Boko Haram 2017'], marker='o', lw=1.1,
            facecolor='none', edgecolor='blue',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Islamic State of Iraq and the Levant (ISIL) 2017'], marker='o', lw=1.1,
            facecolor='none', edgecolor='red',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Al-Qaida in the Arabian Peninsula (AQAP) 2017'], marker='o', lw=1.1,
            facecolor='none', edgecolor='green', 
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in casualties_points],
            [geom.y for geom in casualties_points],
            country_dataframe['Others 2017'], marker='o', lw=1.1,
            facecolor='none', edgecolor='black',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
ax.set_title('Casualties in 2017')
plt.legend()
plt.savefig("casualties_ter.png")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
"""
According to the GTD codebook, 22 different targets are defined for each attack, ranging from militaries, civilians, 
religions authorities or journalists. To see which category has been mostly targeted by the three groups we are analyzing,
we are calculating their occurence in the respective dataset. Doing so will allow us to find the most proeminent features
of each terrorist group and see if we can affiliate other attacks to their techniques
"""

number_targets = 22
bokoharam_target = np.zeros((number_targets, 1))
isil_target = np.zeros((number_targets, 1))
aqap_target = np.zeros((number_targets, 1))
targets_label = [None] * number_targets

def my_autopct(pct):
    return ('%.2f' % pct) if pct > 2 else ''

# Iterating through each dataframe separately

for index, rows in bokoharam_dataframe.iterrows():
    target = rows['targtype1'] - 1
    bokoharam_target[target] += 1
    if targets_label[target] == None:
        targets_label[target] = rows['targtype1_txt']
        
sort_bokoharam_target = np.fliplr([np.argsort(bokoharam_target[:, 0])])[0]
bokoharam_pie_target = np.fliplr([np.sort(bokoharam_target[:, 0])])[0]
        
for index, rows in isil_dataframe.iterrows():
    target = rows['targtype1'] - 1
    isil_target[target] += 1
    if targets_label[target] == None:
        targets_label[target] = rows['targtype1_txt']
        
sort_isil_target = np.fliplr([np.argsort(isil_target[:, 0])])[0]
isil_pie_target = np.fliplr([np.sort(isil_target[:, 0])])[0]
        
for index, rows in aqap_dataframe.iterrows():
    target = rows['targtype1'] - 1
    aqap_target[target] += 1
    if targets_label[target] == None:
        targets_label[target] = rows['targtype1_txt']
        
sort_aqap_target = np.fliplr([np.argsort(aqap_target[:, 0])])[0]
aqap_pie_target = np.fliplr([np.sort(aqap_target[:, 0])])[0]

bokoharam_label_target = [targets_label[i] for i in sort_bokoharam_target]
isil_label_target = [targets_label[i] for i in sort_isil_target]
aqap_label_target = [targets_label[i] for i in sort_aqap_target]
        
fig = plt.figure()

ax1 = fig.add_subplot(131, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax1.pie(bokoharam_pie_target, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.legend(labels=bokoharam_label_target,
          title="Boko Haram Targets",
          loc="best",
          bbox_to_anchor=(0.7, 0.3))
ax1.set_title("Boko Haram")

ax2 = fig.add_subplot(132, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax2.pie(isil_pie_target, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax2.legend(labels=isil_label_target,
          title="ISIL Targets",
          loc="best",
          bbox_to_anchor=(1, 0.3))
ax2.set_title("ISIL")

ax3 = fig.add_subplot(133, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax3.pie(aqap_pie_target, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax3.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax3.legend(labels=aqap_label_target,
          title="AQAP Targets",
          loc="best",
          bbox_to_anchor=(1.3, 0.3))
ax3.set_title("AQAP")
plt.savefig("targets_pie.png")
plt.show()

# %%
"""
According to the GTD codebook, 22 different targets are defined for each attack, ranging from militaries, civilians, 
religions authorities or journalists. To see which category has been mostly targeted by the three groups we are analyzing,
we are calculating their occurence in the respective dataset. Doing so will allow us to find the most proeminent features
of each terrorist group and see if we can affiliate other attacks to their techniques
"""

number_subtargets = 113
bokoharam_subtarget = np.zeros((number_subtargets, 1))
isil_subtarget = np.zeros((number_subtargets, 1))
aqap_subtarget = np.zeros((number_subtargets, 1))
subtargets_label = [None] * number_subtargets

# Iterating through each dataframe separately

for index, rows in bokoharam_dataframe.iterrows():
    if(~np.isnan(rows['targsubtype1'])):
        subtarget = int(rows['targsubtype1'] - 1)
        bokoharam_subtarget[subtarget] += 1
        if subtargets_label[subtarget] == None:
            subtargets_label[subtarget] = rows['targsubtype1_txt']
        
sort_bokoharam_subtarget = np.fliplr([np.argsort(bokoharam_subtarget[:, 0])])[0]
bokoharam_pie_subtarget = np.fliplr([np.sort(bokoharam_subtarget[:, 0])])[0]
        
for index, rows in isil_dataframe.iterrows():
    if(~np.isnan(rows['targsubtype1'])):
        subtarget = int(rows['targsubtype1'] - 1)
        isil_subtarget[subtarget] += 1
        if subtargets_label[subtarget] == None:
            subtargets_label[subtarget] = rows['targsubtype1_txt']
        
sort_isil_subtarget = np.fliplr([np.argsort(isil_subtarget[:, 0])])[0]
isil_pie_subtarget = np.fliplr([np.sort(isil_subtarget[:, 0])])[0]
        
for index, rows in aqap_dataframe.iterrows():
    if(~np.isnan(rows['targsubtype1'])):
        subtarget = int(rows['targsubtype1'] - 1)
        aqap_subtarget[subtarget] += 1
        if subtargets_label[subtarget] == None:
            subtargets_label[subtarget] = rows['targsubtype1_txt']
        
sort_aqap_subtarget = np.fliplr([np.argsort(aqap_subtarget[:, 0])])[0]
aqap_pie_subtarget = np.fliplr([np.sort(aqap_subtarget[:, 0])])[0]

bokoharam_label_subtarget = [subtargets_label[i] for i in sort_bokoharam_subtarget]
isil_label_subtarget = [subtargets_label[i] for i in sort_isil_subtarget]
aqap_label_subtarget = [subtargets_label[i] for i in sort_aqap_subtarget]
        
fig = plt.figure()

subtarg_total = np.sum(bokoharam_pie_subtarget)
bokoharam_legend = []

for perc, label in zip(bokoharam_pie_subtarget, bokoharam_label_subtarget):
    if (perc * 100 / subtarg_total > 2):
        bokoharam_legend.append(label)

ax1 = fig.add_subplot(131, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax1.pie(bokoharam_pie_subtarget, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.legend(labels=bokoharam_legend,
          title="Boko Haram Sub-Targets",
          loc="best",
          bbox_to_anchor=(0.4, 0.3))
ax1.set_title("Boko Haram")

subtarg_total = np.sum(isil_pie_subtarget)
isil_legend = []

for perc, label in zip(isil_pie_subtarget, isil_label_subtarget):
    if (perc * 100 / subtarg_total > 2):
        isil_legend.append(label)

ax2 = fig.add_subplot(132, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax2.pie(isil_pie_subtarget, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax2.legend(labels=isil_legend,
          title="ISIL Sub-Targets",
          loc="best",
          bbox_to_anchor=(1, 0.3))
ax2.set_title("ISIL")

subtarg_total = np.sum(aqap_pie_subtarget)
aqap_legend = []

for perc, label in zip(aqap_pie_subtarget, aqap_label_subtarget):
    if (perc * 100 / subtarg_total > 2):
        aqap_legend.append(label)

ax3 = fig.add_subplot(133, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax3.pie(aqap_pie_subtarget, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax3.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax3.legend(labels=aqap_legend,
          title="AQAP Sub-Targets",
          loc="best",
          bbox_to_anchor=(1.3, 0.3))
ax3.set_title("AQAP")
plt.show()

# %%
"""
In order to study the tactics used by each group, we are using the attacktype feature, which can range from a kidnapping
to a facility attack. According to the codebook, eight categories have been defined, with an additional one used
whenever the modus operandi is unknown
"""

number_attacks = 9
bokoharam_attacks = np.zeros((number_attacks, 1))
isil_attacks = np.zeros((number_attacks, 1))
aqap_attacks = np.zeros((number_attacks, 1))
attack_label = [None] * number_attacks

# Iterating through each dataframe separately

for index, rows in bokoharam_dataframe.iterrows():
    attack = rows['attacktype1'] - 1
    bokoharam_attacks[attack] += 1
    if attack_label[attack] == None:
        attack_label[attack] = rows['attacktype1_txt']
        
sort_bokoharam_attacks = np.fliplr([np.argsort(bokoharam_attacks[:, 0])])[0]
bokoharam_pie_attacks = np.fliplr([np.sort(bokoharam_attacks[:, 0])])[0]
        
for index, rows in isil_dataframe.iterrows():
    attack = rows['attacktype1'] - 1
    isil_attacks[attack] += 1
    if attack_label[attack] == None:
        attack_label[attack] = rows['attacktype1_txt']
        
sort_isil_attacks = np.fliplr([np.argsort(isil_attacks[:, 0])])[0]
isil_pie_attacks = np.fliplr([np.sort(isil_attacks[:, 0])])[0]
        
for index, rows in aqap_dataframe.iterrows():
    attack = rows['attacktype1'] - 1
    aqap_attacks[attack] += 1
    if attack_label[attack] == None:
        attack_label[attack] = rows['attacktype1_txt']
        
sort_aqap_attacks = np.fliplr([np.argsort(aqap_attacks[:, 0])])[0]
aqap_pie_attacks = np.fliplr([np.sort(aqap_attacks[:, 0])])[0]

bokoharam_label_attacks = [attack_label[i] for i in sort_bokoharam_attacks]
isil_label_attacks = [attack_label[i] for i in sort_isil_attacks]
aqap_label_attacks = [attack_label[i] for i in sort_aqap_attacks]
        
fig = plt.figure()

ax1 = fig.add_subplot(131, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax1.pie(bokoharam_pie_attacks, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.legend(labels=bokoharam_label_attacks,
          title="Boko Haram Attacks",
          loc="best",
          bbox_to_anchor=(1.1, 1))
ax1.set_title("Boko Haram")

ax2 = fig.add_subplot(132, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax2.pie(isil_pie_attacks, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax2.legend(labels=isil_label_attacks,
          title="ISIL Attacks",
          loc="best",
          bbox_to_anchor=(1.3, 1))
ax2.set_title("ISIL")

ax3 = fig.add_subplot(133, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax3.pie(aqap_pie_attacks, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax3.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax3.legend(labels=aqap_label_attacks,
          title="AQAP Attacks",
          loc="best",
          bbox_to_anchor=(1.5, 1))
ax3.set_title("AQAP")
plt.show()

# %%
"""
As each terrorist group has different ways of getting hold of weapons and also different budgets related to their strength,
it is also interesting to consider what kind of weapons each of them used most frequently during their attacks, by using
both the weaptype and the weapsubtpe features.

For the weaptype feature, the codebook mentions 13 different categories, from the chemical weapons to the sabotage equipment
"""

number_weap = 13
bokoharam_weap = np.zeros((number_weap, 1))
isil_weap = np.zeros((number_weap, 1))
aqap_weap = np.zeros((number_weap, 1))
weap_label = [None] * number_weap

# Iterating through each dataframe separately

for index, rows in bokoharam_dataframe.iterrows():
    weap = rows['weaptype1'] - 1
    bokoharam_weap[weap] += 1
    if weap_label[weap] == None:
        weap_label[weap] = rows['weaptype1_txt']
                
sort_bokoharam_weap = np.fliplr([np.argsort(bokoharam_weap[:, 0])])[0]
bokoharam_pie_weap = np.fliplr([np.sort(bokoharam_weap[:, 0])])[0]
        
for index, rows in isil_dataframe.iterrows():
    weap = rows['weaptype1'] - 1
    isil_weap[weap] += 1
    if weap_label[weap] == None:
        weap_label[weap] = rows['weaptype1_txt']
        
sort_isil_weap = np.fliplr([np.argsort(isil_weap[:, 0])])[0]
isil_pie_weap = np.fliplr([np.sort(isil_weap[:, 0])])[0]
        
for index, rows in aqap_dataframe.iterrows():
    weap = rows['weaptype1'] - 1
    aqap_weap[weap] += 1
    if weap_label[weap] == None:
        weap_label[weap] = rows['weaptype1_txt']
        
sort_aqap_weap = np.fliplr([np.argsort(aqap_weap[:, 0])])[0]
aqap_pie_weap = np.fliplr([np.sort(aqap_weap[:, 0])])[0]

bokoharam_label_weap = [weap_label[i] for i in sort_bokoharam_weap]
isil_label_weap = [weap_label[i] for i in sort_isil_weap]
aqap_label_weap = [weap_label[i] for i in sort_aqap_weap]
        
fig = plt.figure()

ax1 = fig.add_subplot(131, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax1.pie(bokoharam_pie_weap, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.legend(labels=bokoharam_label_weap,
          title="Boko Haram Weapons",
          loc="best",
          bbox_to_anchor=(0.7, 0.3))
ax1.set_title("Boko Haram")

ax2 = fig.add_subplot(132, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax2.pie(isil_pie_weap, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax2.legend(labels=isil_label_weap,
          title="ISIL Weapons",
          loc="best",
          bbox_to_anchor=(1, 0.3))
ax2.set_title("ISIL")

ax3 = fig.add_subplot(133, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax3.pie(aqap_pie_weap, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax3.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax3.legend(labels=aqap_label_weap,
          title="AQAP Weapons",
          loc="best",
          bbox_to_anchor=(1.3, 0.3))
ax3.set_title("AQAP")
plt.show()

# %%
"""
The weapsubtype feature is divided into 31 categories, but only in the case if the weapon type is either in the chemical,
firearms, explosives, incendiary or melee categories
"""

number_subweap = 31
bokoharam_subweap = np.zeros((number_subweap, 1))
isil_subweap = np.zeros((number_subweap, 1))
aqap_subweap = np.zeros((number_subweap, 1))
subweap_label = [None] * number_subweap

# Iterating through each dataframe separately

for index, rows in bokoharam_dataframe.iterrows():
    if (~np.isnan(rows['weapsubtype1'])):
        subweap = int(rows['weapsubtype1'] - 1)
        bokoharam_subweap[subweap] += 1
        if subweap_label[subweap] == None:
            subweap_label[subweap] = rows['weapsubtype1_txt']
                
sort_bokoharam_subweap = np.fliplr([np.argsort(bokoharam_subweap[:, 0])])[0]
bokoharam_pie_subweap = np.fliplr([np.sort(bokoharam_subweap[:, 0])])[0]
        
for index, rows in isil_dataframe.iterrows():
    if (~np.isnan(rows['weapsubtype1'])):
        subweap = int(rows['weapsubtype1'] - 1)
        isil_subweap[subweap] += 1
        if subweap_label[subweap] == None:
            subweap_label[subweap] = rows['weapsubtype1_txt']
        
sort_isil_subweap = np.fliplr([np.argsort(isil_subweap[:, 0])])[0]
isil_pie_subweap = np.fliplr([np.sort(isil_subweap[:, 0])])[0]
        
for index, rows in aqap_dataframe.iterrows():
    if (~np.isnan(rows['weapsubtype1'])):
        subweap = int(rows['weapsubtype1'] - 1)
        aqap_subweap[subweap] += 1
        if subweap_label[subweap] == None:
            subweap_label[subweap] = rows['weapsubtype1_txt']
        
sort_aqap_subweap = np.fliplr([np.argsort(aqap_subweap[:, 0])])[0]
aqap_pie_subweap = np.fliplr([np.sort(aqap_subweap[:, 0])])[0]

bokoharam_label_subweap = [subweap_label[i] for i in sort_bokoharam_subweap]
isil_label_subweap = [subweap_label[i] for i in sort_isil_subweap]
aqap_label_subweap = [subweap_label[i] for i in sort_aqap_subweap]
        
fig = plt.figure()

subweap_total = np.sum(bokoharam_pie_subweap)
bokoharam_legend = []

for perc, label in zip(bokoharam_pie_subweap, bokoharam_label_subweap):
    if (perc * 100 / subweap_total > 2):
        bokoharam_legend.append(label)

ax1 = fig.add_subplot(131, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax1.pie(bokoharam_pie_subweap, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax1.legend(labels=bokoharam_legend,
          title="Boko Haram Sub-Weapons",
          loc="best",
          bbox_to_anchor=(0.7, 0.3))
ax1.set_title("Boko Haram")

subweap_total = np.sum(isil_pie_subweap)
isil_legend = []

for perc, label in zip(isil_pie_subweap, isil_label_subweap):
    if (perc * 100 / subweap_total > 2):
        isil_legend.append(label)

ax2 = fig.add_subplot(132, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax2.pie(isil_pie_subweap, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax2.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax2.legend(labels=isil_legend,
          title="ISIL Sub-Weapons",
          loc="best",
          bbox_to_anchor=(1, 0.3))
ax2.set_title("ISIL")

subweap_total = np.sum(aqap_pie_subweap)
aqap_legend = []
aqap_subweap_final = []

for perc, label in zip(aqap_pie_subweap, aqap_label_subweap):
    if (perc * 100 / subweap_total > 2):
        aqap_legend.append(label)
        aqap_subweap_final.append(perc * 100 / subweap_total)

ax3 = fig.add_subplot(133, facecolor='w', frame_on=False)
fig.set_size_inches(10.5, 10.5)
    
ax3.pie(aqap_pie_subweap, labels=None, autopct=my_autopct,
        shadow=True, startangle=90)
ax3.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
ax3.legend(labels=aqap_legend,
          title="AQAP Sub-Weapons",
          loc="best",
          bbox_to_anchor=(1.3, 0.3))
ax3.set_title("AQAP")
plt.show()

# %%
"""
In order to start creating edges between our nodes, and thus assigning to each black node one of the three studied
terrorist groups, we are going to study their similarity by comparing their values for some more features than the two
ones displayed above. The selected features are :

 * attacktype1
 * targtype1
 * targsubtype1 (gives more detail about the target)
 * weaptype1
 * weapsubtype1 (more details about the weapon used, such as vehicle, Molotov cocktail, etc...)
"""

bokoharam_size = bokoharam_dataframe['nkill'].size
isil_size = isil_dataframe['nkill'].size
aqap_size = aqap_dataframe['nkill'].size
unclassified_size = unclassified_dataframe['nkill'].size

similitude_bokoharam = np.zeros((unclassified_size, bokoharam_size))

for index_un, rows_un in unclassified_dataframe.iterrows():
    for index_bokoharam, rows_bokoharam in bokoharam_dataframe.iterrows():
        # We compare each feature separately: if they match, we add the percentage of this feature corresponding to the
        # respective group to the similitude percentage
        if (rows_un['country'] == rows_bokoharam['country']):
            similitude_bokoharam[index_un, index_bokoharam] += 0.1
        if (rows_un['provstate'] == rows_bokoharam['provstate']):
            similitude_bokoharam[index_un, index_bokoharam] += 0.1
        if (rows_un['city'] == rows_bokoharam['city']):
            similitude_bokoharam[index_un, index_bokoharam] += 0.1
        if (rows_un['targtype1'] == rows_bokoharam['targtype1']):
            targtype = int(rows_un['targtype1'] - 1)
            similitude_bokoharam[index_un, index_bokoharam] += bokoharam_pie_target[targtype] / bokoharam_size
        if (rows_un['targsubtype1'] == rows_bokoharam['targsubtype1']):
            targsubtype = int(rows_un['targsubtype1'] - 1)
            similitude_bokoharam[index_un, index_bokoharam] += bokoharam_pie_subtarget[targsubtype] / bokoharam_size
        if (rows_un['attacktype1'] == rows_bokoharam['attacktype1']):
            attacktype = int(rows_un['attacktype1'] - 1)
            similitude_bokoharam[index_un, index_bokoharam] += bokoharam_pie_attacks[attacktype] / bokoharam_size
        if (rows_un['weaptype1'] == rows_bokoharam['weaptype1']):
            weaptype = int(rows_un['weaptype1'] - 1)
            similitude_bokoharam[index_un, index_bokoharam] += bokoharam_pie_weap[weaptype] / bokoharam_size
        if (rows_un['weapsubtype1'] == rows_bokoharam['weapsubtype1']):
            weapsubtype = int(rows_un['weapsubtype1'] - 1)
            similitude_bokoharam[index_un, index_bokoharam] += bokoharam_pie_subweap[weapsubtype] / bokoharam_size
            
similitude_isil = np.zeros((unclassified_size, isil_size))

for index_un, rows_un in unclassified_dataframe.iterrows():
    for index_isil, rows_isil in isil_dataframe.iterrows():
        # We compare each feature separately: if they match, we add the percentage of this feature corresponding to the
        # respective group to the similitude percentage
        if (rows_un['country'] == rows_isil['country']):
            similitude_isil[index_un, index_isil] += 0.1
        if (rows_un['provstate'] == rows_isil['provstate']):
            similitude_isil[index_un, index_isil] += 0.1
        if (rows_un['city'] == rows_isil['city']):
            similitude_isil[index_un, index_isil] += 0.1
        if (rows_un['targtype1'] == rows_isil['targtype1']):
            targtype = int(rows_un['targtype1'] - 1)
            similitude_isil[index_un, index_isil] += isil_pie_target[targtype] / isil_size
        if (rows_un['targsubtype1'] == rows_isil['targsubtype1']):
            targsubtype = int(rows_un['targsubtype1'] - 1)
            similitude_isil[index_un, index_isil] += isil_pie_subtarget[targsubtype] / isil_size
        if (rows_un['attacktype1'] == rows_isil['attacktype1']):
            attacktype = int(rows_un['attacktype1'] - 1)
            similitude_isil[index_un, index_isil] += isil_pie_attacks[attacktype] / isil_size
        if (rows_un['weaptype1'] == rows_isil['weaptype1']):
            weaptype = int(rows_un['weaptype1'] - 1)
            similitude_isil[index_un, index_isil] += isil_pie_weap[weaptype] / isil_size
        if (rows_un['weapsubtype1'] == rows_isil['weapsubtype1']):
            weapsubtype = int(rows_un['weapsubtype1'] - 1)
            similitude_isil[index_un, index_isil] += isil_pie_subweap[weapsubtype] / isil_size
            
similitude_aqap = np.zeros((unclassified_size, aqap_size))

for index_un, rows_un in unclassified_dataframe.iterrows():
    for index_aqap, rows_aqap in aqap_dataframe.iterrows():
        # We compare each feature separately: if they match, we add the percentage of this feature corresponding to the
        # respective group to the similitude percentage
        if (rows_un['country'] == rows_aqap['country']):
            similitude_aqap[index_un, index_aqap] += 0.1
        if (rows_un['provstate'] == rows_aqap['provstate']):
            similitude_aqap[index_un, index_aqap] += 0.1
        if (rows_un['city'] == rows_aqap['city']):
            similitude_aqap[index_un, index_aqap] += 0.1
        if (rows_un['targtype1'] == rows_aqap['targtype1']):
            targtype = int(rows_un['targtype1'] - 1)
            similitude_aqap[index_un, index_aqap] += aqap_pie_target[targtype] / aqap_size
        if (rows_un['targsubtype1'] == rows_aqap['targsubtype1']):
            targsubtype = int(rows_un['targsubtype1'] - 1)
            similitude_aqap[index_un, index_aqap] += aqap_pie_subtarget[targsubtype] / aqap_size
        if (rows_un['attacktype1'] == rows_aqap['attacktype1']):
            attacktype = int(rows_un['attacktype1'] - 1)
            similitude_aqap[index_un, index_aqap] += aqap_pie_attacks[attacktype] / aqap_size
        if (rows_un['weaptype1'] == rows_aqap['weaptype1']):
            weaptype = int(rows_un['weaptype1'] - 1)
            similitude_aqap[index_un, index_aqap] += aqap_pie_weap[weaptype] / aqap_size
        if (rows_un['weapsubtype1'] == rows_aqap['weapsubtype1']):
            weapsubtype = int(rows_un['weapsubtype1'] - 1)
            similitude_aqap[index_un, index_aqap] += aqap_pie_subweap[weapsubtype] / aqap_size

# %%
"""
We concatenate the three matrixes together, in order to get the similarity degree of each unclassified node with 
the nodes of the three studied terrorist groups. To consider 
"""
middle = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-5, 
        llcrnrlat=-5,
        urcrnrlon=65,
        urcrnrlat=40,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

similitude_matrix = np.concatenate((similitude_bokoharam, similitude_isil), axis=1)
similitude_matrix = np.concatenate((similitude_matrix, similitude_aqap), axis=1)

number_neighbors = 10

similitude_max = np.zeros((unclassified_size, number_neighbors))
similitude_size = similitude_matrix.shape[1]

bokoharam_similar = pd.DataFrame()
isil_similar = pd.DataFrame()
aqap_similar = pd.DataFrame()


for index_un, index_sim in zip(range(0, unclassified_size), range(0, similitude_size + 1)):
    bokoharam_score = 0
    isil_score = 0
    aqap_score = 0
    
    unclassified_attack = unclassified_dataframe.iloc[[index_un]]
    row = similitude_matrix[:, index_sim]
    if (np.max(row) > 0.5):
        max_index = np.argwhere(row == np.max(row))[:, 0]
    
        for index in max_index:
            if (index < bokoharam_size):
                bokoharam_score += 1
            elif (index > bokoharam_size and index < bokoharam_size + isil_size):
                isil_score += 1
            else:
                aqap_score += 1
            
    if (bokoharam_score > isil_score and bokoharam_score > aqap_score):
        bokoharam_similar = bokoharam_similar.append(unclassified_attack)
    elif (isil_score > bokoharam_score and isil_score > aqap_score):
        isil_similar = isil_similar.append(unclassified_attack)
    elif (aqap_score > bokoharam_score and aqap_score > isil_score):
        aqap_similar = aqap_similar.append(unclassified_attack)
        
similar_bokoharam_points = pd.Series(
                [Point(middle(mapped_x, mapped_y))
                 for mapped_x, mapped_y in zip(bokoharam_similar['longitude'], 
                                               bokoharam_similar['latitude'])])

similar_isil_points = pd.Series(
                [Point(middle(mapped_x, mapped_y))
                 for mapped_x, mapped_y in zip(isil_similar['longitude'], 
                                               isil_similar['latitude'])])

plt.clf()
fig = plt.figure()
ax = fig.add_subplot(111, facecolor='w', frame_on=False)
fig.set_size_inches(18.5, 10.5)  
    
dev = middle.scatter(
            [geom.x for geom in bokoharam_points],
            [geom.y for geom in bokoharam_points],
            20, marker='o', lw=.25,
            facecolor='blue', edgecolor='w', label='Boko Haram',
            alpha=0.9,antialiased=True,
            zorder=2)
dev = middle.scatter(
            [geom.x for geom in isil_points],
            [geom.y for geom in isil_points],
            20, marker='o', lw=.25,
            facecolor='red', edgecolor='w', label='ISIL',
            alpha=0.9,antialiased=True,
            zorder=2)
dev = middle.scatter(
            [geom.x for geom in aqap_points],
            [geom.y for geom in aqap_points],
            20, marker='o', lw=.25,
            facecolor='green', edgecolor='w', label='Al-Qaida in the Arabian Peninsula',
            alpha=0.9,antialiased=True,
            zorder=2)

dev = middle.scatter(
            [geom.x for geom in similar_bokoharam_points],
            [geom.y for geom in similar_bokoharam_points],
            20, marker='o', lw=.25,
            facecolor='deepskyblue', edgecolor='w', label='Attacks similar to Boko Haram',
            alpha=0.9,antialiased=True,
            zorder=2)
dev = middle.scatter(
            [geom.x for geom in similar_isil_points],
            [geom.y for geom in similar_isil_points],
            20, marker='o', lw=.25,
            facecolor='sandybrown', edgecolor='w', label='Attacks similar to ISIL',
            alpha=0.9,antialiased=True,
            zorder=2)

middle.fillcontinents(color='beige',lake_color='lightblue');
middle.drawcountries();
middle.drawmapboundary(fill_color='lightblue');
ax.set_title('Similar attacks from 2014 to 2017')
plt.legend()
plt.savefig("similar_attacks.png")
