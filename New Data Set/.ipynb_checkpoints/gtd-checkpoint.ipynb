# %%
from mpl_toolkits.basemap import Basemap
from shapely.geometry import Point, MultiPoint
import pandas as pd
import matplotlib.pyplot as plt
import mplleaflet
import matplotlib.cm as cm
import matplotlib.colors as co

# To display world map
m = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-155, 
        llcrnrlat=-60,
        urcrnrlon=180,
        urcrnrlat=75,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

europe = Basemap(
        projection='merc',
        ellps = 'WGS84',
        llcrnrlon=-15, 
        llcrnrlat=35,
        urcrnrlon=45,
        urcrnrlat=70,
        lat_ts=0,
        resolution='i',
        suppress_ticks=True)

gtd_dataframe = pd.read_csv('gtd_test.csv', usecols=["country", "region_txt", "longitude", "latitude"])
gtd_dataframe.columns

#gtd_dataframe = gtd_dataframe.dropna()
europe_dataframe = gtd_dataframe.loc[gtd_dataframe['region_txt'] == 'Western Europe']

map_points = pd.Series(
                [Point(m(mapped_x, mapped_y)) 
                 for mapped_x, mapped_y in zip(gtd_dataframe['longitude'],
                                               gtd_dataframe['latitude'])])

europe_points = pd.Series(
                [Point(europe(mapped_x, mapped_y))
                 for mapped_x, mapped_y in zip(europe_dataframe['longitude'], 
                                               europe_dataframe['latitude'])])

amre_points = MultiPoint(list(map_points.values)) 
europe_repoints = MultiPoint(list(europe_points.values))

country = gtd_dataframe['country']
europe_country = europe_dataframe['country']
cmap = plt.cm.jet

norm = co.Normalize(vmin=country.min(), vmax=country.max())
pointcolors = plt.cm.ScalarMappable(norm, cmap)
col = pointcolors.to_rgba(country)

europe_norm = co.Normalize(vmin=europe_country.min(), vmax=europe_country.max())
europecolors = plt.cm.ScalarMappable(europe_norm, cmap)
europe_col = europecolors.to_rgba(europe_country)

plt.clf()
fig = plt.figure()
ax = fig.add_subplot(111, facecolor='w', frame_on=False)
fig.set_size_inches(18.5, 10.5)

# Create a scatterplot on the map
dev = europe.scatter(
            [geom.x for geom in europe_points],
            [geom.y for geom in europe_points],
            20, marker='o', lw=.25,
            facecolor=europe_col, edgecolor='w',
            alpha=0.9,antialiased=True,
            zorder=3)

europe.fillcontinents(color='#555555')
plt.savefig("europe.png")

# %%
gtd_dataframe
# Out:
#           eventid  iyear  imonth  iday  approxdate  extended  resolution  \
# 0    199705180003   1997       5    18         NaN         1  11/14/1997
# 1    199705180004   1997       5    18         NaN         0         NaN
# 2    199705190001   1997       5    19         NaN         0         NaN
# 3    199705190002   1997       5    19         NaN         0         NaN
# 4    199705190003   1997       5    19         NaN         0         NaN
# 5    199705190004   1997       5    19         NaN         0         NaN
# 6    199705200001   1997       5    20         NaN         0         NaN
# 7    199705200002   1997       5    20         NaN         0         NaN
# 8    199705200003   1997       5    20         NaN         0         NaN
# 9    199705200004   1997       5    20         NaN         0         NaN
# 10   199705200005   1997       5    20         NaN         0         NaN
# 11   199705200006   1997       5    20         NaN         0         NaN
# 12   199705200007   1997       5    20         NaN         0         NaN
# 13   199705210001   1997       5    21         NaN         0         NaN
# 14   199705210002   1997       5    21         NaN         0         NaN
# 15   199705210003   1997       5    21         NaN         0         NaN
# 16   199705210004   1997       5    21         NaN         0         NaN
# 17   199705210005   1997       5    21         NaN         1    6/8/1997
# 18   199705210006   1997       5    21         NaN         0         NaN
# 19   199705220001   1997       5    22         NaN         0         NaN
# 20   199705220002   1997       5    22         NaN         0         NaN
# 21   199705220003   1997       5    22         NaN         0         NaN
# 22   199705230001   1997       5    23         NaN         0         NaN
# 23   199705250001   1997       5    25         NaN         0         NaN
# 24   199705250002   1997       5    25         NaN         0         NaN
# 25   199705250003   1997       5    25         NaN         0         NaN
# 26   199705250004   1997       5    25         NaN         0         NaN
# 27   199705250005   1997       5    25         NaN         0         NaN
# 28   199705250006   1997       5    25         NaN         0         NaN
# 29   199705250007   1997       5    25         NaN         0         NaN
# ..            ...    ...     ...   ...         ...       ...         ...
# 97   199706010012   1997       6     1         NaN         0         NaN
# 98   199706010013   1997       6     1         NaN         0         NaN
# 99   199706020001   1997       6     2         NaN         0         NaN
# 100  199706020003   1997       6     2         NaN         0         NaN
# 101  199706020004   1997       6     2         NaN         0         NaN
# 102  199706020006   1997       6     2         NaN         0         NaN
# 103  199706020007   1997       6     2         NaN         1    6/6/1997
# 104  199706020008   1997       6     2         NaN         0         NaN
# 105  199706020009   1997       6     2         NaN         0         NaN
# 106  199706030001   1997       6     3         NaN         0         NaN
# 107  199706030002   1997       6     3         NaN         0         NaN
# 108  199706030003   1997       6     3         NaN         0         NaN
# 109  199706030004   1997       6     3         NaN         0         NaN
# 110  199706030005   1997       6     3         NaN         0         NaN
# 111  199706030006   1997       6     3         NaN         0         NaN
# 112  199706040001   1997       6     4         NaN         0         NaN
# 113  199706040002   1997       6     4         NaN         0         NaN
# 114  199706040003   1997       6     4         NaN         0         NaN
# 115  199706040004   1997       6     4         NaN         0         NaN
# 116  199706040005   1997       6     4         NaN         0         NaN
# 117  199706040006   1997       6     4         NaN         0         NaN
# 118  199706040007   1997       6     4         NaN         0         NaN
# 119  199706040008   1997       6     4         NaN         1    6/9/1997
# 120  199706040009   1997       6     4         NaN         0         NaN
# 121  199706040010   1997       6     4         NaN         0         NaN
# 122  199706040011   1997       6     4         NaN         0         NaN
# 123  199706050001   1997       6     5         NaN         0         NaN
# 124  199706050003   1997       6     5         NaN         0         NaN
# 125  199706050004   1997       6     5         NaN         0         NaN
# 126  199706050005   1997       6     5         NaN         0         NaN
#
#      country       country_txt  region                   region_txt  \
# 0         45          Colombia       3                South America
# 1         45          Colombia       3                South America
# 2        110           Lebanon      10   Middle East & North Africa
# 3        159              Peru       3                South America
# 4         45          Colombia       3                South America
# 5         45          Colombia       3                South America
# 6        109            Latvia       9               Eastern Europe
# 7        153          Pakistan       6                   South Asia
# 8        159              Peru       3                South America
# 9        159              Peru       3                South America
# 10         8            Angola      11           Sub-Saharan Africa
# 11        45          Colombia       3                South America
# 12        45          Colombia       3                South America
# 13        92             India       6                   South Asia
# 14        92             India       6                   South Asia
# 15        34           Burundi      11           Sub-Saharan Africa
# 16        34           Burundi      11           Sub-Saharan Africa
# 17        45          Colombia       3                South America
# 18        45          Colombia       3                South America
# 19       130            Mexico       1                North America
# 20       138           Myanmar       5               Southeast Asia
# 21         6           Algeria      10   Middle East & North Africa
# 22       217     United States       1                North America
# 23        96           Ireland       8               Western Europe
# 24       153          Pakistan       6                   South Asia
# 25       153          Pakistan       6                   South Asia
# 26       153          Pakistan       6                   South Asia
# 27        45          Colombia       3                South America
# 28        45          Colombia       3                South America
# 29        45          Colombia       3                South America
# ..       ...               ...     ...                          ...
# 97        83         Guatemala       2  Central America & Caribbean
# 98       603    United Kingdom       8               Western Europe
# 99       159              Peru       3                South America
# 100        5           Albania       9               Eastern Europe
# 101        6           Algeria      10   Middle East & North Africa
# 102       11         Argentina       3                South America
# 103       45          Colombia       3                South America
# 104       45          Colombia       3                South America
# 105       74           Georgia       7                 Central Asia
# 106       92             India       6                   South Asia
# 107      160       Philippines       5               Southeast Asia
# 108      185             Spain       8               Western Europe
# 109      186         Sri Lanka       6                   South Asia
# 110       45          Colombia       3                South America
# 111       45          Colombia       3                South America
# 112       92             India       6                   South Asia
# 113       95              Iraq      10   Middle East & North Africa
# 114      110           Lebanon      10   Middle East & North Africa
# 115      110           Lebanon      10   Middle East & North Africa
# 116      110           Lebanon      10   Middle East & North Africa
# 117      130            Mexico       1                North America
# 118      130            Mexico       1                North America
# 119      157  Papua New Guinea      12        Australasia & Oceania
# 120      223           Vietnam       5               Southeast Asia
# 121        5           Albania       9               Eastern Europe
# 122       45          Colombia       3                South America
# 123        6           Algeria      10   Middle East & North Africa
# 124       90           Hungary       9               Eastern Europe
# 125       90           Hungary       9               Eastern Europe
# 126       90           Hungary       9               Eastern Europe
#
#                 provstate                       city   latitude   longitude
# 0               Santander                Bucaramanga   7.116294  -73.120026
# 1               Antioquia                    Unknown   7.198606  -75.341218
# 2                   South                    Naqoura  33.118290   35.139866
# 3                    Lima                       Lima -11.967368  -76.978462
# 4                   Cesar         San Diego district  10.333818  -73.181276
# 5                  Bogota                     Bogota   4.667128  -74.106056
# 6                    Riga                       Riga  56.946203   24.104287
# 7                   Sindh                    Karachi  24.891115   67.143311
# 8                    Lima                       Lima -11.967368  -76.978462
# 9                    Lima                       Lima -11.967368  -76.978462
# 10                 Huambo                  Vila Nova -12.638615   16.039174
# 11                Cordoba        San Pelayo district   8.957780  -75.837660
# 12                 Bogota                     Bogota   4.667128  -74.106056
# 13                Manipur           Thoubal district  24.644924   93.999290
# 14                Unknown                   Wangehuk        NaN         NaN
# 15                 Rutana                     Rutana  -3.923747   29.989884
# 16       Bujumbura Mairie                  Bujumbura  -3.375828   29.364107
# 17     Norte de Santander        La Gabarra district   8.998496  -72.897243
# 18                Bolivar             San Estanislao  10.398410  -75.149210
# 19               Guerrero               Chilpancingo  17.551547  -99.500648
# 20                  Kayah                     Loikaw  19.674167   97.209167
# 21                  Blida                   Boufarik  36.574120    2.912140
# 22                 Oregon                   Portland  45.511795 -122.675629
# 23                  Louth                    Dundalk  53.993847   -6.396594
# 24                  Sindh                    Karachi  24.891115   67.143311
# 25                  Sindh                    Karachi  24.891115   67.143311
# 26                  Sindh                    Karachi  24.891115   67.143311
# 27                 Bogota                     Bogota   4.667128  -74.106056
# 28              Risaralda                    Guatica   5.315511  -75.800565
# 29                  Huila                    Acevedo   1.804883  -75.890770
# ..                    ...                        ...        ...         ...
# 97                Unknown  On Inter-American highway        NaN         NaN
# 98       Northern Ireland                 Ballymoney  55.071136   -6.513154
# 99                 Callao                     Callao -12.050981  -77.125985
# 100                Tirana                     Tirana  41.327500   19.818889
# 101               Algiers                    Algiers  36.763763    3.055413
# 102          Buenos Aires               Buenos Aires -34.617680  -58.444435
# 103             Antioquia                   Buritica   6.719613  -75.907029
# 104             Antioquia                    Uramita   6.898522  -76.173320
# 105              Abkhazia              Gali district  42.615404   41.719870
# 106     Jammu and Kashmir                   Srinagar  34.083740   74.789902
# 107  Metropolitian Manila                     Manila  14.596051  120.978666
# 108             Andalusia                    Granada  37.176487   -3.597929
# 109         North Eastern                  illavalai   9.795275   79.989203
# 110                Boyaca            Cubara district   7.000556  -72.108333
# 111             Santander           Sabana de Torres   7.390020  -73.500990
# 112     Jammu and Kashmir                   Handwara  34.399281   74.281273
# 113          Sulaymaniyah               Sulaymaniyah  35.567009   45.385494
# 114                 Beqaa                      Qilya  33.436944   35.655556
# 115                 South                    Jezzine  33.541351   35.586215
# 116               Unknown                Toumat Niha        NaN         NaN
# 117             Zacatecas                 Rio Grande  23.825498 -103.031558
# 118              Veracruz                     Xalapa  19.542624  -96.913744
# 119          Bougainville                    Tinputz  -5.550140  155.007525
# 120           Ho Chi Minh           Ho Chi Minh City  10.829260  106.633072
# 121                   NaN                 Shkallnuer  41.290278   19.516944
# 122             Antioquia                   Medellin   6.242026  -75.564766
# 123                Djelfa                     Djelfa  34.666667    3.250000
# 124              Budapest                   Budapest  47.498406   19.040758
# 125              Budapest                   Budapest  47.498406   19.040758
# 126              Budapest                   Budapest  47.498406   19.040758
#
# [127 rows x 15 columns]
